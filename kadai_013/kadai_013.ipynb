# %%
# 消費税を加えた金額を計算する関数
def calc_tax(price, tax_rate):
    # 消費税を含めた金額を計算
    total = price * (1 + tax_rate / 100)
    return total

# 関数の呼び出し
result = calc_tax(110, 10)

# 結果の表示
print(result)
# Out:
# 121.00000000000001
