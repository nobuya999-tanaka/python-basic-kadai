# %%
# リストを作成
array = [
    "月曜日は晴れです",
    "火曜日は雨です",
    "水曜日は晴れです",
    "木曜日は晴れです",
    "金曜日は曇りです",
    "土曜日は曇りのち雨です",
    "日曜日は雷雨です"
]

# 水曜日（インデックス2）を取り出して出力
print(array[2])
# Out:
# 水曜日は晴れです

# %%
# ディクショナリを作成
weather = {
    "月曜日": "晴れ",
    "火曜日": "雨",
    "水曜日": "晴れ",
    "木曜日": "晴れ",
    "金曜日": "曇り",
    "土曜日": "曇りのち雨",
    "日曜日": "雷雨"
}

# 水曜日の天気を取り出して出力
print("水曜日は" + weather["水曜日"] + "です")
# Out:
# 水曜日は晴れです
