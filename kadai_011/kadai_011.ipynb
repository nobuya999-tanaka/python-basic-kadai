# %%
array = ["水","金","地","火","木","土","天","海","冥"]

# forループ
for element in array:
    print(element)

# whileループ
i = 0
while i < 9:
    print(array[i])
    i += 1
# Out:
# 水
# 金
# 地
# 火
# 木
# 土
# 天
# 海
# 冥
# 水
# 金
# 地
# 火
# 木
# 土
# 天
# 海
# 冥
